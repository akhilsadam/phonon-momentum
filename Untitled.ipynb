# %%
from matplotlib import pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
fig = plt.figure()
plt.plot([0,1],[2,3])
pp = PdfPages('foo.pdf')
pp.savefig(fig)
pp.
pp.savefig(fig)
pp.close()
